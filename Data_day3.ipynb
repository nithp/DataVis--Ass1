# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
import seaborn as sns
from numpy.random import randn, randint, uniform, sample

# %%
#ASSINGMENT 3 - PLOTTING FMRI DATA SET
fmri= sns.load_dataset('fmri')
fmri.head(10)
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970
# 5      s9         18  stim  parietal -0.103513
# 6      s8         18  stim  parietal -0.064408
# 7      s7         18  stim  parietal -0.060526
# 8      s6         18  stim  parietal -0.007029
# 9      s5         18  stim  parietal -0.040557

# %%
fmri.subject.unique()
# Out:
# array(['s13', 's5', 's12', 's11', 's10', 's9', 's8', 's7', 's6', 's4',
#        's3', 's2', 's1', 's0'], dtype=object)

# %%
fmri.region.unique()
# Out:
# array(['parietal', 'frontal'], dtype=object)

# %%
fmri.describe()
# Out:
#          timepoint       signal
# count  1064.000000  1064.000000
# mean      9.000000     0.003540
# std       5.479801     0.093930
# min       0.000000    -0.255486
# 25%       4.000000    -0.046070
# 50%       9.000000    -0.013653
# 75%      14.000000     0.024293
# max      18.000000     0.564985

# %%
sns.relplot(x='timepoint', y= 'signal', data=fmri)

# %%
sns.relplot(x='timepoint', y= 'signal' ,kind='line', data=fmri)

# %%
sns.relplot(x='timepoint', y= 'signal' ,kind='line', data=fmri,hue = 'event')

# %%
sns.relplot(data = fmri, x = "timepoint", y = "signal", hue = "region", style = "region")

# %%
sns.relplot(x = 'timepoint', y = 'signal', hue = 'region',data = fmri)

# %%
fmri.event.unique()
# Out:
# array(['stim', 'cue'], dtype=object)

# %%
sns.relplot(data = fmri, x = "timepoint", y = "signal",  style = "region", col="event")

# %%
sns.relplot(data = fmri, x = "timepoint", y = "signal", kind="line", ci= 'sd')

# %%
sns.relplot(data = fmri, x = "timepoint", y = "signal", kind="line", estimator=None)

# %%
sns.relplot(data = fmri, x = "timepoint", y = "signal", hue = "region", style = "event", kind='line')

# %%
sns.lineplot(data=fmri, x="timepoint", y="signal", hue="event", err_style="bars")

# %%
sns.lineplot(data = fmri, x = "timepoint", y = "signal", hue = "subject", style = "region")

# %%
sns.catplot(x='region',y='signal',kind='box',data=fmri, hue='event')

# %%
sns.catplot(x='event',y='timepoint',kind='box',data=fmri, hue='region')

# %%
sns.catplot(x='region',y='signal',kind='box', data=fmri, hue='event',dodge=False)

# %%
sns.boxplot(data = fmri, x = 'timepoint', y = 'signal', hue = 'region')

# %%
sns.catplot(x='event',y='timepoint',kind='boxen',data=fmri)

# %%
sns.catplot(x='event',y='timepoint',kind='violin',data=fmri, hue='region')
